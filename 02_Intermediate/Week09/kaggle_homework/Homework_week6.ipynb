# %% [markdown]
# #  Kaggle forecasting Example

# %%
import pandas as pd
import random

# %% [markdown]
# # Load Train Dataset

# %% [markdown]
# ####  - dfX_train   is the training data
# ####  - dfY_train   is the  target
#
# ####  - target is SalePrice

# %%
dfX_train = pd.read_csv("train_data.csv")
dfX_train
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0        1  527359050           20        RL          80.0     10400   Pave
# 1        2  906475070           60        RL           NaN     28698   Pave
# 2        3  534429030           90        RL          70.0      9842   Pave
# 3        4  535451170           90        RL          60.0      7200   Pave
# 4        5  902109130          190        RM          63.0      7627   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2339  2340  527226040          190        RL         195.0     41600   Pave
# 2340  2341  528290090           60        RL           NaN      7750   Pave
# 2341  2342  528490080           60        FV          64.0      8791   Pave
# 2342  2343  902109160           50        RM          81.0      7308   Pave
# 2343  2344  907227110           85        RL          60.0      7200   Pave
#
# ...

# %%
dfY_train = pd.read_csv("train_target.csv") 

dfY_train
# Out:
#         Id  SalePrice
# 0        1     152000
# 1        2     185000
# 2        3     101800
# 3        4      90000
# 4        5      94550
# ...    ...        ...
# 2339  2340     155000
# 2340  2341     176000
# 2341  2342     207500
# 2342  2343     122250
# 2343  2344     133900
#
# [2344 rows x 2 columns]

# %% [markdown]
# # Load Test Dataset

# %%
# Load Test Dataset

df_Xtest = pd.read_csv('test_data.csv')
df_Xtest
# Out:
#        Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    2345  903427090           70        RM           NaN      5100   Pave
# 1    2346  527450460          160        RM          21.0      1890   Pave
# 2    2347  908128100           60        RL          62.0      7162   Pave
# 3    2348  907135180           20        RL          60.0      8070   Pave
# 4    2349  910200080           30        RM          50.0      7000   Pave
# ..    ...        ...          ...       ...           ...       ...    ...
# 581  2926  916455110           80        RL          73.0      9590   Pave
# 582  2927  528176030           20        RL         100.0     14836   Pave
# 583  2928  528188020          120        RL          48.0      3480   Pave
# 584  2929  908102160           85        RL          75.0      9825   Pave
# 585  2930  908102260           20        RL          75.0      9937   Pave
#
# ...

# %% [markdown]
# # Load Example Submission

# %%
df_Solution = pd.read_csv('sample_submission.csv')
df_Solution
# Out:
#        Id  SalePrice
# 0    2345     161000
# 1    2346     116000
# 2    2347     196500
# 3    2348     123600
# 4    2349     126000
# ..    ...        ...
# 581  2926          0
# 582  2927          0
# 583  2928          0
# 584  2929          0
# 585  2930          0
#
# [586 rows x 2 columns]

# %% [markdown]
# # Random Create Submission

# %%
df_Solution['SalePrice'] = [random.uniform(5000, 1000000) for _ in range(len(df_Solution))]

df_Solution
# Out:
#        Id      SalePrice
# 0    2345  553229.365637
# 1    2346  595823.446792
# 2    2347  536316.588146
# 3    2348  394520.070834
# 4    2349  467767.237460
# ..    ...            ...
# 581  2926  770288.083181
# 582  2927   28864.875090
# 583  2928  737848.936879
# 584  2929  314004.764561
# 585  2930  770911.084366
#
# [586 rows x 2 columns]

# %% [markdown]
# # Save Submission

# %%
df_Solution.to_csv('demo_submission1.csv', index=False)
