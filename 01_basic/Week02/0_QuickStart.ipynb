# %% [markdown]
# https://opentyphoon.ai/
#
#
#
# https://platform.openai.com/

# %%
import IPython
import sys

def clean_notebook():
    IPython.display.clear_output(wait=True)
    print("Notebook cleaned.")

# !pip install openai
# !pip install gradio
# !pip install python-dotenv

# Clean up the notebook
clean_notebook()
# Out:
# Notebook cleaned.

# %%
# %%writefile .env
# OPENAI_API_KEY=your_api_key_here
# OPENTYPHOON_API_KEY=api_key_here

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# Load environment variables
load_dotenv()
# Out:
# True

# %%
import os
from openai import OpenAI

openai_client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
model_name = "o4-mini"    

# openai_client = OpenAI(api_key=os.environ.get("OPENTYPHOON_API_KEY"),base_url="https://api.opentyphoon.ai/v1")
# model_name = "typhoon-instruct"

# %% [markdown]
# # Basic

# %%
user_prompt = "ขอวิธีทำข้าวผัดกระเพราไก่หน่อยครับ"

completion = openai_client.chat.completions.create(
    model=model_name ,
    messages=[
        {"role": "user", "content": user_prompt},
    ],
 
)

response = completion.choices[0].message.content
print(response)
# Out:
# ส่วนผสม (สำหรับ 1–2 ที่)
# 1. ข้าวสวยหุงสุก (ค้างคืนหรืออุ่นให้ร่วน) 1 จาน
# 2. อกไก่หั่นชิ้นพอคำ หรือสับหยาบ 100–120 กรัม
# 3. กระเทียมสับหยาบ 2–3 กลีบ
# 4. พริกขี้หนูสวนบุบหยาบ (ปรับตามความเผ็ด) 5–8 เม็ด
# 5. น้ำมันพืช 1–2 ช้อนโต๊ะ
# 6. น้ำปลา 1½–2 ช้อนชา
# 7. ซอสหอยนางรม 1 ช้อนชา
# 8. น้ำตาลทรายหยิบมือเล็กน้อย
# 9. ใบกะเพราเด็ดเป็นใบ 1–2 กำมือ
# 10. ไข่ดาว (ถ้าชอบ) 1 ฟอง
#
# วิธีทำ
# 1. เตรียมข้าวสวยให้ร่วน ไม่ติดกันเป็นก้อน ถ้ายังอุ่นไม่พอก็ตักใส่กะละมังผสมพัดลมเป่าให้เย็นเล็กน้อยก่อนผัด
# 2. ตั้งกระทะบนไฟกลาง ใส่น้ำมันพืช พอร้อน ใส่กระเทียมสับลงเจียวเล็กน้อยจนเหลืองหอม
# 3. ใส่พริกขี้หนูบุบ ผัดให้เข้ากัน ตบท้ายด้วยเนื้อไก่ ผัดจนสุกทั่วกัน (ใช้ตะหลิวเกลี่ยให้ไก่โดนความร้อนสม่ำเสมอ)
# 4. เติมข้าวสวยลงไป ผัดให้กระจายทั่วกระทะ ใช้ไฟกลาง-ค่อนแรง ปรุงรสด้วยน้ำปลา ซอสหอยนางรม และน้ำตาลทราย ชิมรสตามชอบ (เค็ม–หวานเล็กน้อย)
# 5. พอรสชาติเข้าที่กันดีแล้ว ใส่ใบกะเพราลงไป ผัดแค่พอเหี่ยวเล็กน้อย ปิดไฟทันที เพื่อให้ใบกะเพราหอม เขียวสด ไม่คล้ำ
# 6. ตักเสิร์ฟร้อน ๆ พร้อมไข่ดาวกรอบขอบ (ถ้าชอบ)
#
# เคล็ดลับเพิ่มเติม
# • ถ้าอยากให้ข้าวผัดร่วนกระเทาะ ใช้มือนวดข้าวก่อนผัดเล็กน้อย หรือเติมน้ำมันมะพร้าวแทนน้ำมันพืชเล็กน้อย
# • ปรุงรสตามชอบ อาจบีบน้ำมะนาวเพิ่มความเปรี้ยวสดชื่นตอนเสิร์ฟได้
# • เพิ่มเครื่องเคียง เช่น แตงกวา มะเขือเทศหั่น แครอทซอย ช่วยให้จานดูสวยและได้วิตามินมากขึ้น
#
# ข้าวผัดกระเพราไก่พร้อมแล้ว! ขอให้สนุกกับการทำอาหาร และอร่อยนะครับ

# %%
import gradio as gr


# Example prompts
examples = [
    ["บอกวิธีเลี้ยงแมว 7 ตัว"],
    ["เล่าประวัติของกรุงเทพมหานคร"],
    ["วิธีการทำอาหารไทยยอดนิยม"],
    ["แนะนำสถานที่ท่องเที่ยวในประเทศไทย"],
    ["เขียนบทความเกี่ยวกับการดูแลสุขภาพจิต"]
]

def chat(user_prompt,temperature, max_token=256):
        completion = openai_client.chat.completions.create(
        model=model_name ,
        messages=[
            {"role": "user", "content": user_prompt},
        ],
        temperature=0.8,
        max_tokens=400,
        )

        response = completion.choices[0].message.content
        return response


# Create Gradio interface
interface = gr.Interface(
    fn=chat,
    inputs=[
        gr.Textbox(lines=2, placeholder="Enter your prompt here..."),
        gr.Slider(minimum=0.1, maximum=1.0, step=0.1, value=0.85, label="Temperature"),
        gr.Slider(minimum=0.1, maximum=1024, step=1, value=256, label="token")
    ],
    outputs=gr.Textbox(lines=5),
    title="Thai Language Blog Generator",
    description="Enter a topic to generate a well-structured 256-word Thai language blog.",
    examples=examples
)

# Launch the interface
interface.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://b0491679d0de840355.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b0491679d0de840355.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ![](https://deeplearningcourses.com/notebooks_v3_pxl?sc=AVRK7SgM9ASkQf5TAqs_wA&n=Quick+Start)
