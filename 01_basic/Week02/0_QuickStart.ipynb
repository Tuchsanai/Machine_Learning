# %% [markdown]
# https://opentyphoon.ai/
#
#
#
# https://platform.openai.com/

# %%
import IPython
import sys

def clean_notebook():
    IPython.display.clear_output(wait=True)
    print("Notebook cleaned.")

# !pip install openai
# !pip install gradio
# !pip install python-dotenv

# Clean up the notebook
clean_notebook()
# Out:
# Notebook cleaned.

# %%
# %%writefile .env
# OPENAI_API_KEY=your_api_key_here
# OPENTYPHOON_API_KEY=api_key_here

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# Load environment variables
load_dotenv()
# Out:
# True

# %%
import os
from openai import OpenAI

openai_client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
model_name = "gpt-4.1"    

# openai_client = OpenAI(api_key=os.environ.get("OPENTYPHOON_API_KEY"),base_url="https://api.opentyphoon.ai/v1")
# model_name = "typhoon-instruct"

# %% [markdown]
# # Basic

# %% [markdown]
# **พารามิเตอร์สำคัญใน `openai_client.chat.completions.create`**
#
# | พารามิเตอร์   | ใช้ทำอะไร                                             | ค่า-ยิ่งมาก/น้อยส่งผลอย่างไร                                                                                                                                                  | ค่าปกติ (ถ้าไม่กำหนด)                    |
# | ------------- | ----------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ---------------------------------------- |
# | `temperature` | ควบคุม “ความสุ่ม” (creativity) ของคำตอบ               | - **ต่ำ (≈ 0-0.3)** → คำตอบคาดเดาได้ คล้ายเดิมทุกครั้ง  <br>- **กลาง (≈ 0.4-0.7)** → สมดุลระหว่างแม่นยำกับหลากหลาย  <br>- **สูง (≈ 0.8-2.0)** → คำตอบหลากหลาย/พลิกแพลงมากขึ้น | 1.0                                      |
# | `max_tokens`  | กำหนด **จำนวนโทเคน** สูงสุดที่โมเดลสามารถสร้างในคำตอบ | - **น้อย** → คำตอบสั้น กระทัดรัด  <br>- **มาก** → คำตอบยาว รายละเอียดเยอะ (แต่ใช้เครดิตมากขึ้น)                                                                               | แตกต่างตามรุ่นโมเดล (เช่น 16k หรือ 128k) |
#
# ### สรุปสั้น ๆ
#
# * `temperature` เหมือน “ปรับรสชาติ” — อุณหภูมิต่ำ = รสเรียบ, อุณหภูมิสูง = รสจัดหลากหลาย
# * `max_tokens` คือ “ข้อจำกัดความยาว” ของคำตอบ ยิ่งมากยิ่งยาว (และใช้โควตา API มากขึ้น)
#
# > **เคล็ดลับ**
# >
# > * ถ้าต้องการคำตอบทางเทคนิคหรือโค้ดที่แม่นยำ ใช้ `temperature` ต่ำ ๆ (0 – 0.3)
# > * ถ้าอยากได้ไอเดียสร้างสรรค์ เช่น สตอรี่หรือสูตรอาหารใหม่ ๆ เพิ่ม `temperature` (≥ 0.8)
# > * ปรับ `max_tokens` ให้พอดีกับความยาวที่ต้องการ เพื่อลดค่าใช้จ่ายและเวลารอผล

# %%
user_prompt = "ขอวิธีทำข้าวผัดกระเพราไก่หน่อยครับ"

completion = openai_client.chat.completions.create(
    model=model_name ,
    messages=[
        {"role": "user", "content": user_prompt},
    ],
    
    temperature=0.8,
    max_tokens=400,
)

response = completion.choices[0].message.content
print(response)
# Out:
# แน่นอนครับ! นี่คือวิธีทำ **ข้าวผัดกระเพราไก่** แบบง่ายๆ อร่อยและเผ็ดหอมสมใจ
#
# ---
#
# ### ส่วนผสม
#
# - ข้าวสวย 1 ถ้วย (ข้าวเย็นจะดีมาก)
# - อกไก่หรือสันในไก่ หั่นชิ้นเล็ก 100 กรัม
# - กระเทียมสับ 1 ช้อนโต๊ะ
# - พริกขี้หนูซอย 5-10 เม็ด (ปรับตามชอบ)
# - น้ำมันพืช 1 ช้อนโต๊ะ
# - ซอสหอยนางรม 1 ช้อนโต๊ะ
# - ซีอิ๊วขาว 1 ช้อนโต๊ะ
# - น้ำตาลทราย ½ ช้อนชา
# - ใบกระเพราเด็ด 1 ถ้วย
# - (ถ้าชอบไข่ดาวด้วยก็เตรียมไข่ 1 ฟอง)
#
# ---
#
# ### วิธีทำ
#
# 1. **ตั้งกระทะ** ใส่น้ำมันพืชให้ร้อน ใส่กระเทียมและพริกขี้หนูลงไปผัดจนหอม
# 2. **ใส่ไก่** ผัดให้ไก่สุกทั่ว
# 3. **ปรุงรส** ใส่ซอสหอยนางรม ซีอิ๊วขาว และน้ำตาล ผัดให้เข้ากันดี
# 4. **ใส่ข้าวสวย** ลงไปผัดให้เข้ากัน คลุกเคล้าให้ร่วน ไม่แฉะ
# 5. **ใส่ใบกระเพรา** ผัดเร็วๆ พอใบเหี่ยว ปิดไฟ
# 6. **ตักใส่จาน** เสิร์ฟคู่ไข่ดาว (ถ้าชอบ) และแตงกว

# %% [markdown]
# # play with multiple choice questions

# %%
examples = [
    "บอกวิธีเลี้ยงแมว 7 ตัว",
    "เล่าประวัติของกรุงเทพมหานคร",
    "วิธีการทำอาหารไทยยอดนิยม",
    "แนะนำสถานที่ท่องเที่ยวในประเทศไทย",
    "เขียนบทความเกี่ยวกับการดูแลสุขภาพจิต"
]
examples
# Out:
# ['บอกวิธีเลี้ยงแมว 7 ตัว',
#  'เล่าประวัติของกรุงเทพมหานคร',
#  'วิธีการทำอาหารไทยยอดนิยม',
#  'แนะนำสถานที่ท่องเที่ยวในประเทศไทย',
#  'เขียนบทความเกี่ยวกับการดูแลสุขภาพจิต']

# %% [markdown]
# # test for loop

# %%
for index, question in enumerate(examples):
    print(f"Question {index + 1}: {question}")
# Out:
# Question 1: บอกวิธีเลี้ยงแมว 7 ตัว
# Question 2: เล่าประวัติของกรุงเทพมหานคร
# Question 3: วิธีการทำอาหารไทยยอดนิยม
# Question 4: แนะนำสถานที่ท่องเที่ยวในประเทศไทย
# Question 5: เขียนบทความเกี่ยวกับการดูแลสุขภาพจิต

# %%
for index, question in enumerate(examples):

    print(f"Question {index + 1}: {question}")

    
    completion = openai_client.chat.completions.create(
        model=model_name,
        messages=[
            {"role": "user", "content": question},
        ],
        temperature=0.8,
        max_tokens=400,
    )   
    response = completion.choices[0].message.content
    print(f"Answer {index + 1}: {response}\n")  
    print("-" * 50)  # Separator for clarity
# Out:
# Question 1: บอกวิธีเลี้ยงแมว 7 ตัว
# Answer 1: การเลี้ยงแมว 7 ตัวพร้อมกัน ต้องมีการจัดการที่ดี ทั้งเรื่องอาหาร สุขอนามัย พื้นที่ และความใส่ใจในแต่ละตัว นี่คือวิธีดูแลและแนวทางที่ควรคำนึงถึง:
#
# **1. พื้นที่เพียงพอ**
# - ควรมีพื้นที่ให้แมวทุกตัวเดิน วิ่ง เล่น และนอนอย่างอิสระ
# - จัดมุมพักผ่อน ที่ลับเล็บ คอนโดแมว หรือชั้นปีนป่ายสำหรับแต่ละตัว
#
# **2. กระบะทรายและความสะอาด**
# - ควรมีกระบะทรายอย่างน้อย 4-5 ใบ (จำนวนแมวลบ 1 หรือมากกว่า)
# - ตักอึและฉี่ออกทุกวัน เปลี่ยนทรายเป็นประจำ ลดกลิ่นและเชื้อโรค
#
# **3. อาหารและน้ำ**
# - จัดชามอาหารและน้ำให้เพียงพอ หลีกเลี่ยงการแย่งกันกิน
# - อาจต้องแยกชามสำหรับแมวบางตัวที่ขี้อายหรือถูกแย่ง
# - ให้อาหารตามวัยและสุขภาพของแต่ละตัว
#
# **4. สุขภาพและวัคซีน**
# - นำแมวไปตรวจสุขภาพและฉีดวัคซีนตามกำหนด
# - ทำหมันทุกตัวเพื่อลดปัญหาทะเลาะหรือขยายพันธุ์
# - สังเกตอาการป่วยและพาไปพบสัตวแพทย์หากผิดปกติ
#
# **5. การสร้างความสัมพันธ์**
# - ให้เวลาเล่นกับแมวแต่ละตัว ไม่ควรละเลยใคร
# - ใช้ของเล่นหลากหลาย ลดความเครียดและความเบื่อ
#
# **6. รับ
#
# --------------------------------------------------
# Question 2: เล่าประวัติของกรุงเทพมหานคร
# Answer 2: กรุงเทพมหานคร หรือที่รู้จักกันทั่วไปว่า "กรุงเทพฯ" เป็นเมืองหลวงและเมืองที่ใหญ่ที่สุดของประเทศไทย มีประวัติศาสตร์ยาวนานและสำคัญในฐานะศูนย์กลางการเมือง เศรษฐกิจ วัฒนธรรม และการคมนาคมของประเทศ
#
# ### ประวัติความเป็นมา
#
# 1. **ยุคก่อนกรุงรัตนโกสินทร์**
#    พื้นที่ที่เป็นกรุงเทพฯ ในปัจจุบัน เดิมเรียกว่า "บางกอก" เป็นชุมชนขนาดเล็ก ตั้งอยู่ริมฝั่งแม่น้ำเจ้าพระยา มีบทบาทสำคัญในฐานะจุดจอดเรือและศูนย์กลางการค้าขายในระหว่างเมืองหลวงเก่าของไทย เช่น กรุงศรีอยุธยา และกรุงธนบุรี
#
# 2. **กรุงธนบุรี**
#    หลังการเสียกรุงศรีอยุธยาในปี พ.ศ. 2310 สมเด็จพระเจ้าตากสินมหาราชได้สถาปนา "กรุงธนบุรี" ขึ้นเป็นราชธานีใหม่ ซึ่งอยู่ฝั่งตะวันตกของแม่น้ำเจ้าพระยา
#
# 3. **การสถาปนากรุงเทพมหานคร**
#    ในปี พ.ศ. 2325 พระบาทสมเด็จพระพุทธยอดฟ้าจุฬาโลกมหาราช (รัชกาลที่ 1) ได้สถาปนากรุงเทพมหานครขึ้นเป็นราชธานีใหม่ แทนกรุงธนบุรี โดยย้ายเมืองหลวงมายังฝั่งตะวันออกของแม่น้ำเจ้าพระยา และตั้งชื่อว่า "**กรุงเทพมหานคร บวรรัตนโกสินทร์ มหินทรายุธยา มหาดิลกภพ นพรัตนราช
#
# --------------------------------------------------
# Question 3: วิธีการทำอาหารไทยยอดนิยม
# Answer 3: แน่นอน! นี่คือวิธีการทำอาหารไทยยอดนิยม 3 เมนู พร้อมขั้นตอนและส่วนประกอบแบบง่ายๆ:
#
# ---
#
# ### 1. **ผัดไทย**
#
# **ส่วนผสม**
# - เส้นจันทน์ (เส้นผัดไทย) 100 กรัม
# - กุ้งสด 5-6 ตัว (ล้างและปอกเปลือก)
# - เต้าหู้เหลืองหั่นชิ้นเล็ก 2 ช้อนโต๊ะ
# - ไข่ไก่ 1 ฟอง
# - ถั่วงอก 1 ถ้วย
# - กุยช่ายหั่นท่อน 1/2 ถ้วย
# - หอมแดงซอย 1 ช้อนโต๊ะ
# - ถั่วลิสงคั่วบด 2 ช้อนโต๊ะ
# - น้ำตาลปี๊บ 1 ช้อนโต๊ะ
# - น้ำปลา 1 ช้อนโต๊ะ
# - น้ำมะขามเปียก 2 ช้อนโต๊ะ
# - น้ำมันสำหรับผัด
#
# **วิธีทำ**
# 1. ผสมน้ำตาลปี๊บ น้ำปลา และน้ำมะขามเปียก พักไว้
# 2. ตั้งกระทะใส่น้ำมัน ใส่หอมแดงซอย, เต้าหู้ ผัดจนหอม
# 3. ใส่กุ้งลงผัดพอสุก ขยับของไปข้างกระทะ ตอกไข่ลงไป คนให้ไข่สุก
# 4. ใส่เส้นจันทน์ เติมน้ำเล็กน้อย ผัดให้เส้นนุ่ม
# 5. เทซอสมะขามที่เตรียมไว้ลงไป ผัดให้เข้ากัน
# 6. ใส่ถั่วงอก กุยช่าย ถั่วลิสง ผัดเบาๆ
# 7. ตักใส่จ
#
# --------------------------------------------------
# Question 4: แนะนำสถานที่ท่องเที่ยวในประเทศไทย
# Answer 4: แน่นอนค่ะ! ประเทศไทยมีสถานที่ท่องเที่ยวหลากหลายประเภท ทั้งธรรมชาติ วัฒนธรรม ทะเล ภูเขา และเมืองใหญ่ นี่คือตัวอย่างสถานที่ท่องเที่ยวที่น่าสนใจ:
#
# **ภาคเหนือ**
# - **เชียงใหม่:** ดอยสุเทพ ดอยอินทนนท์ ถนนนิมมานฯ วัดพระสิงห์ ประตูท่าแพ สวนสัตว์เชียงใหม่
# - **เชียงราย:** วัดร่องขุ่น วัดร่องเสือเต้น สามเหลี่ยมทองคำ ดอยแม่สลอง ดอยตุง
# - **ลำปาง:** วัดพระธาตุลำปางหลวง รถม้าลำปาง
#
# **ภาคกลาง**
# - **กรุงเทพมหานคร:** วัดพระแก้ว วัดโพธิ์ พระบรมมหาราชวัง ถนนข้าวสาร ตลาดน้ำอัมพวา (สมุทรสงคราม)
# - **พระนครศรีอยุธยา:** อุทยานประวัติศาสตร์พระนครศรีอยุธยา วัดมหาธาตุ วัดไชยวัฒนาราม
#
# **ภาคตะวันออก**
# - **ชลบุรี:** พัทยา เกาะล้าน สวนนงนุช เขาชีจรรย์
# - **ระยอง:** เกาะเสม็ด หาดแม่รำพึง
#
# **ภาคตะวันออกเฉียงเหนือ (อีสาน)**
# - **นครราชสีมา:** อุทยานแห่งชาติเขาใหญ่ วังน้ำเขียว
# - **อุบลราชธานี:** สามพันโบก ผาแต้ม วัดสิรินธรวรารามภูพร้าว
#
# **ภาคใต้**
# - **ภูเก็ต:** หาดป่าตอง แหลมพรหม
#
# --------------------------------------------------
# Question 5: เขียนบทความเกี่ยวกับการดูแลสุขภาพจิต
# Answer 5: ### การดูแลสุขภาพจิต สำคัญอย่างไรและทำอย่างไรได้บ้าง
#
# #### สุขภาพจิตคืออะไร
#
# สุขภาพจิต คือ ภาวะความสมดุลทางอารมณ์ ความคิด และพฤติกรรม เป็นสิ่งที่มีผลต่อความรู้สึก การตัดสินใจ การเข้าสังคม รวมถึงคุณภาพชีวิตโดยรวม สุขภาพจิตที่ดีจะช่วยให้รับมือกับความเครียดได้ดี ปรับตัวเข้ากับสถานการณ์ต่าง ๆ และมีความสัมพันธ์ที่ดีต่อผู้อื่น
#
# #### ทำไมต้องดูแลสุขภาพจิต
#
# ปัจจุบันคนจำนวนมากประสบกับความเครียด วิตกกังวล หรือภาวะซึมเศร้าโดยไม่รู้ตัว หากละเลยอาจส่งผลกระทบต่อร่างกายและชีวิตประจำวัน เช่น นอนไม่หลับ เบื่ออาหาร ขาดสมาธิ หรือความสัมพันธ์กับผู้อื่นแย่ลง การดูแลสุขภาพจิตจึงสำคัญไม่แพ้กับการดูแลร่างกาย
#
# #### วิธีดูแลสุขภาพจิต
#
# 1. **หมั่นสำรวจความรู้สึกตนเอง**
#    สังเกตอารมณ์ ความคิด และพฤติกรรมของตัวเองอยู่เสมอ เมื่อรู้สึกเครียดหรือเศร้า ควรยอมรับและหาสาเหตุ เพื่อหาทางจัดการอย่างเหมาะสม
#
# 2. **พักผ่อนให้เพียงพอ**
#    การนอนหลับอย่างมีคุณภาพ ช่วยฟื้นฟูทั้งร่างกายและจิตใจ ลดความเครียดและช่วยให้คิดบวกมากขึ้น
#
# 3. **ออกกำลังกายสม่ำเสมอ**
#    การเคลื่อนไหวร่างกาย เช่น
#
# --------------------------------------------------

# %% [markdown]
# ![](https://deeplearningcourses.com/notebooks_v3_pxl?sc=AVRK7SgM9ASkQf5TAqs_wA&n=Quick+Start)
